# %% [markdown]
# # 1. WC '16 Contest 1 J1 - A Spooky Season
# https://dmoj.ca/problem/wc16c1j1

# %%
s = int(input())

print('sp'+'o'*s+'ky')
# Out:
# 5
# spoooooky

# %% [markdown]
# # 2. WC '15 Contest 2 J1 - A New Hope
# https://dmoj.ca/problem/wc15c2j1

# %%
s = int(input())
result = 'A long time ago in a galaxy '
if s > 1:
    for i in range(s-1):
        result += 'far, '
result += 'far '+'away...'
print(result)
# Out:
# 5
# A long time ago in a galaxy far, far, far, far, far away...

# %% [markdown]
# # 3. CCC '13 J1 - Next in line
# https://dmoj.ca/problem/ccc13j1

# %%
a = int(input())
b = int(input())

c = b*2 - a
print(c)
# Out:
# 10
# 10
# 10

# %% [markdown]
# # 4. WC '17 Contest 1 J2 - How's the Weather?
# https://dmoj.ca/problem/wc17c1j2

# %%
temp = int(input())
temp2 = 9 * temp / 5 + 32
print(temp2)
# Out:
# 20
# 68.0
