# %%
import os, cv2, time
import tensorflow as tf
import tqdm
import numpy as np
import math
from itertools import product
import matplotlib.pyplot as plt
from PIL import Image

# %%
STICKER_PATH = '/content/drive/MyDrive/aiffel_dataset/GD14_face_sticker/blush.png'
img_sticker = cv2.imread(STICKER_PATH)
print(img_sticker.shape)
plt.imshow(cv2.cvtColor(img_sticker, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# (288, 881, 3)

# %%
box_width = 50
box_height = 50

# %%
sticker_width = img_sticker.shape[0]
sticker_height = img_sticker.shape[1]

resize_sticker_width = box_width / sticker_width
sticker_width = sticker_width * resize_sticker_width
print(sticker_width)

sticker_height = sticker_height * resize_sticker_width
print(sticker_height)
# Out:
# 50.0
# 152.95138888888889

# %%
sticker_width = round(sticker_width)
sticker_width
# Out:
# 50

# %%
sticker_height = round(sticker_height)
sticker_height
# Out:
# 153
